# %% [markdown]
# # Semana 4 - Variáveis Aleatórias Discretas

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 4

# %% [markdown]
# <img src="imagens/semana-4/s4-q1.png" alt="Semana 4 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q2.png" alt="Semana 4 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q3.png" alt="Semana 4 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q4.png" alt="Semana 4 - Questão 4" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q5.png" alt="Semana 4 - Questão 5" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q6.png" alt="Semana 4 - Questão 6" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-4/s4-q7.png" alt="Semana 4 - Questão 7" size="100%" position="center" />
