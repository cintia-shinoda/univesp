# %% [markdown]
# # Semana 1

# %% [markdown]
# [Playlist](https://youtube.com/playlist?list=PLxI8Can9yAHfsMKsLoHT5rKwOEffPgyWe&si=0xqpxVz74WRK-SO9)

# %% [markdown]
# ##

# %% [markdown]
# ### Semana 1 - Introdução à Ciência de Dados
# https://youtu.be/gru85-WFjDU

# %% [markdown]
# ### Videoaula 1 - Introdução a Ciência de Dados
# https://youtu.be/z6jbqkmshig

# %% [markdown]
# #### Quiz - videoaula 1

# %% [markdown]
# - Ciência de Dados e a Indústria 4.0
# - Mercado Profissional para Ciência de Dados

# %% [markdown]
# ## Atividade Avaliativa - Semana 1

# %% [markdown]
# <img src="imagens/semana-1/s1-q1-a.png" alt="Semana 1 - Questão 1-a" size="100%" position="center" />
# <img src="imagens/semana-1/s1-q1-b.png" alt="Semana 1 - Questão 1-b" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-1/s1-q2.png" alt="Semana 1 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-1/s1-q3.png" alt="Semana 1 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-1/s1-q4.png" alt="Semana 1 - Questão 4" size="100%" position="center" />
