# %% [markdown]
# # Semana 6 - Predição e KNN (K-Nearest Neighbors)

# %% [markdown]
# ## Desafio

# %% [markdown]
# ## Revisitando Conhecimentos

# %% [markdown]
# ##

# %% [markdown]
# ### Videoaula 16 - Predição de Dados

# %% [markdown]
# #### Quiz - videoaula 16

# %% [markdown]
# ### Videoaula 17 - Algoritmo KNN (K-Nearest Neighbors) e Avaliação de Modelos Preditivos

# %% [markdown]
# #### Quiz - videoaula 17

# %% [markdown]
# ### Videoaula 18 - Entrevista Renata Castanha

# %% [markdown]
# #### Quiz - videoaula 18

# %% [markdown]
# ## Materiais Base

# %% [markdown]
# ### Texto-base I:

# %% [markdown]
# ### Texto-base II:

# %% [markdown]
# ### Texto-base III:

# %% [markdown]
# ## Quiz: Objeto Educacional

# %% [markdown]
# ## Aprofundando o tema

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# ## Atividade Avaliativa - Semana 6

# %% [markdown]
# <img src="imagens/semana-6/s6-q1.png" alt="Semana 6 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q2-a.png" alt="Semana 6 - Questão 2-a" size="100%" position="center" />
# <img src="imagens/semana-6/s6-q2-b.png" alt="Semana 6 - Questão 2-b" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q3.png" alt="Semana 6 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q4.png" alt="Semana 6 - Questão 4" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q5.png" alt="Semana 6 - Questão 5" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q6.png" alt="Semana 6 - Questão 6" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q7.png" alt="Semana 6 - Questão 7" size="100%" position="center" />

# %% [markdown]
# # Em síntese
