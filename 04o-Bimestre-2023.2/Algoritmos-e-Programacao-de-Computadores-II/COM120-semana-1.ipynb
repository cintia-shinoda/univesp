# %% [markdown]
# # Semana 1 - Gerenciamento de Memória, Arquivo e Depuração de Programas

# %% [markdown]
# ##

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 1

# %% [markdown]
# <!-- <img src="imagens/semana-1/s1-q1.png" alt="Semana 1 - Questão 1" size="100%" position="center" /> -->
