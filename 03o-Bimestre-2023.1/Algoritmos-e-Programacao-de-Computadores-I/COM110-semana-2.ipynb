# %% [markdown]
# # Semana 2 - Tipos de Dados (Parte 1)

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 2
