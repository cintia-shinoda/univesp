# %% [markdown]
# # Semana 1 - Introdução a Algoritmos e a Python

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 1
