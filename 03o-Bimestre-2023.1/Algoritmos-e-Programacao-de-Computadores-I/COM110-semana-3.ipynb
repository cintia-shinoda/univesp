# %% [markdown]
# # Semana 3 - Tipos de Dados (Parte 2)

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 3
