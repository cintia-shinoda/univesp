# %% [markdown]
# # Semana 7 - Vetores e Matrizes

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 7
