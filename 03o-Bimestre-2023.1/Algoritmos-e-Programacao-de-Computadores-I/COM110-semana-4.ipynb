# %% [markdown]
# # Semana 4 - Criação de Programas

# %% [markdown]
# ## .

# %% [markdown]
# ### Videoaula -

# %% [markdown]
# #### Quiz - videoaula

# %% [markdown]
# ## Atividade Avaliativa - Semana 4
