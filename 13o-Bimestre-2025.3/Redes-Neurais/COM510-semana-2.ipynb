# %% [markdown]
# # Semana 2 - Arquiteturas de Redes, Preparação dos Dados e Modelos Lineares

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Texto-base 1

# %% [markdown]
# ### Videoaula 4 - Principais Arquiteturas de Redes Neurais

# %% [markdown]
# #### Quiz - videoaula 4

# %% [markdown]
# ### Texto-base 2

# %% [markdown]
# ### Texto-base 3

# %% [markdown]
# ### Videoaula 5 - Preparação dos Dados para Treinamento das Redes Neurais

# %% [markdown]
# #### Quiz - videoaula 5

# %% [markdown]
# ### Texto-base 4

# %% [markdown]
# ### Texto-base 5

# %% [markdown]
# ### Videoaula 6 - Primeiros Modelos - Perceptron e Adaline

# %% [markdown]
# #### Quiz - videoaula 6

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Aprofundando o tema

# %% [markdown]
# ### 1

# %% [markdown]
# ### 2

# %% [markdown]
# ### 3

# %% [markdown]
# ### 4

# %% [markdown]
# ### 5

# %% [markdown]
# ### 6

# %% [markdown]
# ## Em Síntese

# %% [markdown]
# ## Atividade Avaliativa - Semana 2

# %% [markdown]
# <img src="imagens/semana-2/s2-q1.png" alt="Semana 2 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q2.png" alt="Semana 2 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q3.png" alt="Semana 2 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q4.png" alt="Semana 2 - Questão 4" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q5.png" alt="Semana 2 - Questão 5" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q6.png" alt="Semana 2 - Questão 6" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q7.png" alt="Semana 2 - Questão 7" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-2/s2-q8.png" alt="Semana 2 - Questão 8" size="100%" position="center" />
