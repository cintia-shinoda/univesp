# %% [markdown]
# # Semana 5 - Modelos de Redes Neurais Generativas

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Inteligência Artificial: Uma Abordagem Moderna - Seção 21.7.1 | Stuart Russell e Peter Norvig

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 60 - Variational Autoencoders (VAEs) - Definição, Redução de Dimensionalidade, Espaço Latente e Regularização | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 61 - A Matemática dos Variational Autoencoders (VAEs) | Data Science Academy

# %% [markdown]
# ### Videoaula 13 - Autoencoders Variacionais (VAE)

# %% [markdown]
# https://youtu.be/CxkllRnwNvs

# %% [markdown]
# #### Quiz - videoaula 13

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 54 - Introdução às Redes Adversárias Generativas (GANs - Generative Adversarial Networks) | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 55 - Geração de Variáveis Aleatórias - Uma das Bases dos Modelos Generativos em GANs | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 56 - Modelos Generativos - O Diferencial das GANs | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 57 - Os Detalhes Matemáticos das GANs | Data Science Academy

# %% [markdown]
# ### Videoaula 14 - Redes Neurais Adversárias Generativas (GAN)

# %% [markdown]
# https://youtu.be/Wi4jBUjwMYM

# %% [markdown]
# #### Quiz - videoaula 14

# %% [markdown]
# ### Videoaula 15 - Modelos Generativos: Aplicações e Práticas

# %% [markdown]
# https://youtu.be/v7FN7RlYnzo

# %% [markdown]
# #### Quiz - videoaula 15

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Exercício de Apoio

# %% [markdown]
# ## Atividade Avaliativa - Semana 5

# %% [markdown]
# ## Aprofundando o Tema

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# Dive Into Deep Learning - Seção 17.1 | Aston Zhang et al.

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# Variational Autoencoders | Wikipedia

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# Generative Adversarial Network | Wikipedia

# %% [markdown]
# ## Em Síntese

# %% [markdown]
# [ ] Conheci o que são os modelos generativos;
#
# [ ] Compreendi como são formados e como funcionam os VAEs;
#
# [ ] Compreendi a estrutura e o funcionamento das redes GANs;
#
# [ ] Aprendi a implementar e treinar modelos generativos.

# %% [markdown]
# ## Atividade Avaliativa - Semana 5

# %% [markdown]
# <img src="imagens/semana-5/s5-q1.png" alt="Semana 5 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q2.png" alt="Semana 5 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q3.png" alt="Semana 5 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q4.png" alt="Semana 5 - Questão 4" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q5.png" alt="Semana 5 - Questão 5" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q6.png" alt="Semana 5 - Questão 6" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q7.png" alt="Semana 5 - Questão 7" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-5/s5-q8.png" alt="Semana 5 - Questão 8" size="100%" position="center" />
