# %% [markdown]
# # Semana 6 - Aprendizado por Reforço

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 62 - O que é Aprendizagem por Reforço? | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 63 - Aplicações da Aprendizagem por Reforço no Mundo Real | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 64 - Componentes do Aprendizado por Reforço | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 65 - Distribuições de Probabilidade, Redes Neurais e Reinforcement Learning | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 66 - Algoritmos de Agente Baseado em IA com Reinforcement Learning - Parte 1 | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning - Capítulo 67 - Algoritmo de Agente Baseado em IA com Reinforcement Learning - Parte 2 | Data Science Academy

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 68 - Algoritmo de Agente Baseado em IA com Reinforcement Learning - Q-Learning | Data Science Academy

# %% [markdown]
# ### Videoaula 16 - Aprendizado por Reforço

# %% [markdown]
# https://youtu.be/5TIxUEqWc2A

# %% [markdown]
# #### Quiz - videoaula 16

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Deep Learning Book - Capítulo 70 - Deep Q-Network e Processos de Decisão de Markov | Data Science Academy

# %% [markdown]
# ### Videoaula 17 - "Aprendizado por Reforço e as Redes Neurais"

# %% [markdown]
# https://youtu.be/H5cBWL94y3c

# %% [markdown]
# #### Quiz - videoaula 17

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Atividade Avaliativa - Semana 6

# %% [markdown]
# ## Aprofundando o Tema

# %% [markdown]
# ### Matéria de Apoio

# %% [markdown]
# [O que é Aprendizagem por Reforço - IA Expert Academy](https://youtu.be/5u8yNEN5arQ)

# %% [markdown]
# ### Matéria de Apoio

# %% [markdown]
# [Introdução ao Aprendizado por Reforço Profundo (Veja de 10min até 66 min) - EBAC ONLINE](https://youtu.be/GWQY3XVUf4g)

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# [Deep Learning: Introdução ao Aprendizado por Reforço | Fernando J. Von Zuben](https://ava.univesp.br/bbcswebdav/xid-14341047_1)

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# A Revolução do Aprendizado Profundo - Capítulo 10 - Aprendizado por Recompensa | Terrence Sejowski

# %% [markdown]
# ### Material de Apoio

# %% [markdown]
# Inteligência Artificial: Uma Abordagem Moderna - Capítulo 22: Aprendizado por Reforço | Stuart J. Russell e Peter Norvig

# %% [markdown]
# ## Em Síntese

# %% [markdown]
# - [ ] Conheci o paradigma de aprendizado por reforço;
# - [ ] Aprendi sobre os principais componentes relacionados ao aprendizado por reforço;
# - [ ] Conheci algumas de suas principais aplicações;
# - [ ] Entendi o algoritmo Q-Learning;
# - [ ] Aprendi a modelar um sistema de aprendizado por reforço para tratar problemas reais, como um agente em um jogo;
# - [ ] Compreendi o que é o aprendizado por reforço profundo.

# %% [markdown]
# ## Atividade Avaliativa - Semana 6

# %% [markdown]
# <img src="imagens/semana-6/s6-q1.png" alt="Semana 6 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q2.png" alt="Semana 6 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q3.png" alt="Semana 6 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q4.png" alt="Semana 6 - Questão 4" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q5.png" alt="Semana 6 - Questão 5" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q6.png" alt="Semana 6 - Questão 6" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-6/s6-q7.png" alt="Semana 6 - Questão 7" size="100%" position="center" />
