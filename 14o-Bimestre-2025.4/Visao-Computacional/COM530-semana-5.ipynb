# %% [markdown]
# # Semana 5 - Segmentação de Imagens

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Videoaula 13 - Segmentação de Imagens

# %% [markdown]
# https://youtu.be/eOrBkDDWpIA

# %% [markdown]
# #### Quiz - videoaula 13

# %% [markdown]
# ### Videoaula 14 - Limiarização

# %% [markdown]
# https://youtu.be/rx5aMzd738c

# %% [markdown]
# #### Quiz - videoaula 14

# %% [markdown]
# ### Videoaula 15 - Prática de Segmentação Semântica com CNN

# %% [markdown]
# https://youtu.be/DsXb22zSsrU

# %% [markdown]
# #### Quiz - videoaula 15

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Processamento Digital de Imagens - Capítulo 10 | Rafael C. Gonzalez e Richard E. Woods (3ª edição)

# %% [markdown]
# ### Texto-base 2

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seção 6.4 p.387-396 | Richard Szeliski

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Atividade Avaliativa - Semana 5

# %% [markdown]
# ## Aprofundando o Tema

# %% [markdown]
# ### Texto de Apoio 1

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seção 7.2, p.455-466 | Richard Szeliski

# %% [markdown]
# ### Texto de Apoio

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seção 7.5, p.483-491 |  Richard Szeliski

# %% [markdown]
# ## Exercício de Apoio

# %% [markdown]
# ## Em Síntese

# %% [markdown]
#  [ ] Compreendi os conceitos básicos de segmentação de imagens;
#
#  [ ] Conheci métodos tradicionais para detecção de pontos, linhas e bordas em imagens;
#
#  [ ] Conheci diferentes abordagens de limiarização para segmentação de imagens;
#
#  [ ] Aprendi como algoritmos de aprendizado de máquina podem ser utilizados para segmentação de imagens;
#  [ ] Utilizei a rede neural convolucional para segmentação de imagens.
