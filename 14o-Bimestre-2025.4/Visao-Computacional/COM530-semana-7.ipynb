# %% [markdown]
# # Semana 7 - Reconhecimento de Objetos

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Videoaula 19 - Reconhecimento de Objetos

# %% [markdown]
# https://youtu.be/QBkizr0hrxA

# %% [markdown]
# #### Quiz - videoaula 19

# %% [markdown]
# ### Videoaula 20 - Prática com Deep Learning para Classificação de Imagens

# %% [markdown]
# https://youtu.be/CmMubEjR1Mk

# %% [markdown]
# #### Quiz - videoaula 20

# %% [markdown]
# ### Videoaula 21 - Prática com Reconhecimento Facial

# %% [markdown]
# https://youtu.be/hNm2aY2pzJw

# %% [markdown]
# #### Quiz - videoaula 21

# %% [markdown]
# ### Texto-base 1

# %% [markdown]
# Processamento Digital de Imagens - Capítulo 12 | Rafael C. Gonzales e Richard E. Woods - 3ª Edição

# %% [markdown]
# ### Texto-base 2

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seções 6.1 e 6.3, p.343-349 e 370-387 | Richard Szeliski

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Aprofundando o Tema

# %% [markdown]
# ### Texto de Apoio

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seção 8.1, p.503-514 | Richard Szeliski

# %% [markdown]
# ## Em Síntese

# %% [markdown]
# [ ]  Compreendi os fundamentos de reconhecimento de objetos em imagens digitais;
#
# [ ] Conheci diferentes técnicas de reconhecimento de objetos em imagens digitais;
#
# [ ]  Conheci as diferentes abordagens de classificação de imagens;
#
# [ ] Conheci diversas aplicações de reconhecimento de objetos;
# [ ] Utilizei algoritmos de aprendizado de máquina, mais especificamente redes neurais profundas, para classificação de imagens;
#
# [ ] Utilizei algoritmos de aprendizado de máquina para reconhecimento facial.

# %% [markdown]
# ## Atividade Avaliativa - Semana 7

# %% [markdown]
# <img src="imagens/semana-7/s7-q1.png" alt="Semana 7 - Questão 1" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-7/s7-q2.png" alt="Semana 7 - Questão 2" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-7/s7-q3.png" alt="Semana 7 - Questão 3" size="100%" position="center" />

# %% [markdown]
# <img src="imagens/semana-7/s7-q4.png" alt="Semana 7 - Questão 4" size="100%" position="center" />
