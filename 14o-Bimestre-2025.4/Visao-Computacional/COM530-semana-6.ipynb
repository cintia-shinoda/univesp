# %% [markdown]
# # Semana 6 - Classificação de Imagens

# %% [markdown]
# ## Desafio

# %% [markdown]
# ##

# %% [markdown]
# ### Videoaula 16 - Representação e Descrição

# %% [markdown]
# https://youtu.be/ieTKBApouUc

# %% [markdown]
# #### Quiz - videoaula 16

# %% [markdown]
# ### Videoaula 17 - Classificação de Imagens

# %% [markdown]
# https://youtu.be/ktWfxo0LJaw

# %% [markdown]
# #### Quiz - videoaula 17

# %% [markdown]
# ### Videoaula 18 - Prática de classificação de imagens baseada em características

# %% [markdown]
# https://youtu.be/TIlxHazr3yw

# %% [markdown]
# #### Quiz - videoaula 18

# %% [markdown]
# ### Texto-base

# %% [markdown]
# Processamento Digital de Imagens - 3ª Edição - Capítulo 11 | Rafael C. Gonzales e Richard E. Woods

# %% [markdown]
# ### Texto-base 2

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seção 6.2, p.349-370 | Richard Szeliski

# %% [markdown]
# ## Quiz Objeto Educacional

# %% [markdown]
# ## Atividade Avaliativa - Semana 6

# %% [markdown]
# ## Aprofundando o Tema

# %% [markdown]
# ### Texto de Apoio

# %% [markdown]
# Computer Vision: Algorithms and Applications - Seções 6.5 a 6.7, p.396-413 | Richard Szeliski

# %% [markdown]
# ## Em Síntese

# %% [markdown]
# [ ] Compreendi os conceitos básicos de representação e descrição de imagens;
#
# [ ] Conheci diferentes descritores de imagens;
#
# [ ] Aprendi os fundamentos de classificação de imagens;
#
# [ ] Aprendi como os algoritmos de aprendizado de máquina podem ser utilizados para classificação de imagens baseada em características;
#
# [ ] Utilizei aprendizado de máquina para classificação de imagens baseada em características.
